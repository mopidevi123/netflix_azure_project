# %% [markdown]
# ###Silver notebook lookup tables

# %% [markdown]
# ####Parameters

# %%
dbutils.widgets.text("sourcefolder", "netflix_directors")
dbutils.widgets.text("targetfolder", "netflix_directors")

# %% [markdown]
# ####Variables

# %%
var_src_folder = dbutils.widgets.get("sourcefolder")
var_trg_folder = dbutils.widgets.get("targetfolder")

# %%
print(var_src_folder)

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(f"abfss://bronze@pravdatalake.dfs.core.windows.net/{var_src_folder}")

# %%
df.display()

# %%
df.write.format("delta")\
    .mode("append")\
    .option("path", f"abfss://silver@pravdatalake.dfs.core.windows.net/{var_trg_folder}")\
    .save()
